# %%
private_key = 'a57b3a36-1b34-4792-91b2-c3cbc3b0678a'

# %%
from vapi_python import Vapi

# %%
help(Vapi.__init__)
# Out:
# Help on function __init__ in module vapi_python.vapi_python:
#
# __init__(self, *, api_key, api_url='https://api.vapi.ai')
#     Initialize self.  See help(type(self)) for accurate signature.

# %%
# pip install vapi
from vapi_python import Vapi

vapi = Vapi(api_key='a57b3a36-1b34-4792-91b2-c3cbc3b0678a') # Get your private api key from the dashboard

async def create_call():
  return await vapi.calls.create(
    phone_number_id="2d4432c6-0749-45af-9433-b5984088e157", # Create a free phone number in the dashboard
    customer={"number": "+48786332265"}, # Your customer's phone number
    assistant={
      "model": {
        "provider": "openai",
        "model": "gpt-4o",
        "messages": [
          {
            "role": "system",
            "content": "You are a helpful AI assistant. Keep your responses concise and friendly."
          }
        ]
      }
    }
  )
  return await response
create_call()
# Out:
# <coroutine object create_call at 0x115a0cf40>
